# %% [markdown]
# # Housing Market

# %% [markdown]
# ### Introduction:
#
# This time we will create our own dataset with fictional numbers to describe a house market. As we are going to create random data don't try to reason of the numbers.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Create 3 differents Series, each of length 100, as follows:
# 1. The first a random number from 1 to 4
# 2. The second a random number from 1 to 3
# 3. The third a random number from 10,000 to 30,000

# %%
df1 = pd.DataFrame(np.random.randint(1,4,size=(100, 1)))
df1
# Out:
#     0
# 0   1
# 1   3
# 2   3
# 3   2
# 4   1
# .. ..
# 95  2
# 96  1
# 97  2
# 98  1
# 99  1
#
# [100 rows x 1 columns]

# %%
df2 = pd.DataFrame(np.random.randint(1,3,size=(100, 1)))
df2
# Out:
#     0
# 0   1
# 1   2
# 2   1
# 3   2
# 4   1
# .. ..
# 95  1
# 96  2
# 97  2
# 98  1
# 99  1
#
# [100 rows x 1 columns]

# %%
df3 = pd.DataFrame(np.random.randint(10000,30000,size=(100, 1)))
df3
# Out:
#         0
# 0   24702
# 1   14777
# 2   23487
# 3   23863
# 4   17051
# ..    ...
# 95  11295
# 96  29000
# 97  28203
# 98  25507
# 99  10861
#
# [100 rows x 1 columns]

# %% [markdown]
# ### Step 3. Let's create a DataFrame by joinning the Series by column

# %%
data1=pd.concat([df1, df2, df3], axis=1)
data1
# Out:
#     0  0      0
# 0   1  1  24702
# 1   3  2  14777
# 2   3  1  23487
# 3   2  2  23863
# 4   1  1  17051
# .. .. ..    ...
# 95  2  1  11295
# 96  1  2  29000
# 97  2  2  28203
# 98  1  1  25507
# 99  1  1  10861
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
data1.columns=['bedrs', 'bathrs', 'price_sqr_meter']
data1
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       1       1            24702
# 1       3       2            14777
# 2       3       1            23487
# 3       2       2            23863
# 4       1       1            17051
# ..    ...     ...              ...
# 95      2       1            11295
# 96      1       2            29000
# 97      2       2            28203
# 98      1       1            25507
# 99      1       1            10861
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigcolumn=pd.concat([df1, df2, df3], axis=0)
bigcolumn
# Out:
#         0
# 0       1
# 1       3
# 2       3
# 3       2
# 4       1
# ..    ...
# 95  11295
# 96  29000
# 97  28203
# 98  25507
# 99  10861
#
# [300 rows x 1 columns]

# %% [markdown]
# ### Step 6. Oops, it seems it is going only until index 99. Is it true?

# %%
no

# %% [markdown]
# ### Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
bigcolumn.reset_index()
# Out:
#      index      0
# 0        0      1
# 1        1      3
# 2        2      3
# 3        3      2
# 4        4      1
# ..     ...    ...
# 295     95  11295
# 296     96  29000
# 297     97  28203
# 298     98  25507
# 299     99  10861
#
# [300 rows x 2 columns]
